# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path= r'C:\Users\jphil\OneDrive\Documents\CareerFoundry Data Analytics\Data Immersion\Achievement 4\Data'

# %%
customers= pd.read_csv(os.path.join(path, 'Original Data', 'customers.csv'), index_col=False)

# %% [markdown]
# # 01 Data Wrangling

# %%
customers.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.rename(columns= {'Surname': 'Last Name'}, inplace=True)

# %%
customers.head()
# Out:
#    user_id First Name Last Name  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.rename(columns= {'n_dependants': 'number_of_dependants'}, inplace=True)

# %%
customers.head()
# Out:
#    user_id First Name Last Name  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
customers.describe()
# Out:
#              user_id            Age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
#I decided that the date_joined column was not relevant to my analysis
cust=customers.drop(columns= ['date_joined'])

# %%
cust.head()
# Out:
#    user_id First Name Last Name  Gender       STATE  Age  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48
# 1    33890   Patricia      Hart  Female  New Mexico   36
# 2    65803    Kenneth    Farley    Male       Idaho   35
# 3   125935   Michelle     Hicks  Female        Iowa   40
# 4   130797        Ann   Gilmore  Female    Maryland   26
#
#    number_of_dependants fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
cust.dtypes
# Out:
# user_id                  int64
# First Name              object
# Last Name               object
# Gender                  object
# STATE                   object
# Age                      int64
# number_of_dependants     int64
# fam_status              object
# income                   int64
# dtype: object

# %%
#cheacking for mixed data types
for col in cust.columns.tolist():
  weird = (cust[[col]].map(type) != cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (cust[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
cust['First Name']=cust['First Name'].astype('str')

# %%
#checking missing values
cust.isnull().sum()
# Out:
# user_id                 0
# First Name              0
# Last Name               0
# Gender                  0
# STATE                   0
# Age                     0
# number_of_dependants    0
# fam_status              0
# income                  0
# dtype: int64

# %%
#checking for duplicates
cust_dups=cust[cust.duplicated()]

# %%
#there are no duplicate rows
cust_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, STATE, Age, number_of_dependants, fam_status, income]
# Index: []

# %%
ords_prods=pd.read_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_flagged.pkl'), compression= 'infer')

# %%
#checking data type for the key column
ords_prods.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# orders_day_of_week           int64
# order_hour                   int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# _merge                    category
# Unnamed: 0                 float64
# product_name                object
# aisle_id                   float64
# department_id              float64
# prices                     float64
# price_range_loc             object
# busiest day                 object
# busiest_day                 object
# busiest_days                object
# busiest_period_of_day       object
# max_order                    int64
# loyalty_flag                object
# avg_price                  float64
# spending_flag               object
# median_days                float64
# frequency_flag              object
# dtype: object

# %%
ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    11.1         196                  1          0   both
# 1                    11.1       14084                  2          0   both
# 2                    11.1       12427                  3          0   both
# 3                    11.1       26088                  4          0   both
# 4                    11.1       26405                  5          0   both
#
#    ...     busiest day     busiest_day    busiest_days  busiest_period_of_day  \
# ...

# %%
#dropping some unnecessary columns
ords_prods1=ords_prods.drop(columns= ['_merge', 'busiest_day', 'busiest_days'])

# %%
ords_prods['user_id']=ords_prods['user_id'].astype('str')

# %%
cust['user_id']=cust['user_id'].astype('str')

# %%
#merging the two dataframes using user_id as the key
custs_ords_prods = ords_prods1.merge(cust, on = 'user_id', indicator = True)

# %%
#exporting combined dataset
custs_ords_prods.to_pickle(os.path.join(path, 'Prepared Data', 'custs_ords_prods.pkl'))
